# %%
from riverrem.REMMaker import REMMaker

# %%
# Provide the DEM file path and desired output directory
rem_maker = REMMaker(dem='I:\Planning\GIS\Assets\Raster Data\DEM\Rajshai\ASTGTMV003_N23E088_dem.tif')
# create an REM
rem = rem_maker.make_rem()
# Out:
# <>:2: DeprecationWarning: invalid escape sequence \P
# <>:2: DeprecationWarning: invalid escape sequence \P
# C:\Users\User\AppData\Local\Temp\ipykernel_7144\1100118989.py:2: DeprecationWarning: invalid escape sequence \P
#   rem_maker = REMMaker(dem='I:\Planning\GIS\Assets\Raster Data\DEM\Rajshai\ASTGTMV003_N23E088_dem.tif')
# [INFO] 2025-05-16 17:13:00,837 - Getting DEM projection.
# [INFO] 2025-05-16 17:13:00,838 - Reading DEM as array.
# [INFO] 2025-05-16 17:13:00,887 - Getting DEM bounds.
# [INFO] 2025-05-16 17:13:00,887 - Mapping array indices to coordinates.
# [INFO] 2025-05-16 17:13:00,888 - Finding river centerline.
# ...

# %%
# create an REM visualization with the given colormap
rem_maker.make_rem_viz(cmap='cool')
# Out:
# [INFO] 2025-05-16 17:11:41,968 -
# Blending REM with hillshade.
# WARNING: NoData value not found for input DEM. Assuming NoData value is 0.
#
# Making multidirectional hillshade raster.
# Tiling and compressing raster.
# Saved ./.cache\ASTGTMV003_N23E088_dem_hillshade.tif.
# WARNING: NoData value not found for input DEM. Assuming NoData value is 0.
#
# Making color relief map with cmap=Spectral.
# Tiling and compressing raster.
# Saved ./.cache\ASTGTMV003_N23E088_dem_REM_color-relief.tif.
#
# Generating .png file.
# Saved ./.cache\ASTGTMV003_N23E088_dem_REM_color-relief.png.
#
# Making hillshade-color composite raster.
# Tiling and compressing raster.
# Saved ./ASTGTMV003_N23E088_dem_hillshade-color.tif.
#
# Generating .png file.
# Saved ./ASTGTMV003_N23E088_dem_hillshade-color.png.
# './ASTGTMV003_N23E088_dem_hillshade-color.tif'
