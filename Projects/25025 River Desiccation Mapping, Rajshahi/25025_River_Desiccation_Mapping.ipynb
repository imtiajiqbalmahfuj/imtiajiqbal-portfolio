# %% [markdown]
# <style>
# /* --- 0. CONTAINER FIX: Ensure the entire notebook is responsive --- */
# body {
#     overflow-x: hidden !important; /* Prevent page-level horizontal scroll */
# }
# div#notebook-container, .container {
#     width: 100% !important;
#     max-width: 100% !important;
#     min-width: 0 !important;
# }
#
# /* --- 1. HIDE PROMPTS --- */
# .prompt,
# .input_prompt,
# .output_prompt,
# .jp-InputPrompt {
#     display: none !important;
# }
#
# /* --- 2. DESKTOP/TABLET: ENFORCE HORIZONTAL SCROLL (Default for > 480px) --- */
# /* Targets all code/text areas */
# div.input_area pre,
# .jp-InputArea-editor pre,
# .code_cell pre,
# .output_area pre,
# div.text_cell pre {
#     white-space: pre !important;
#     overflow-x: auto !important;
#     width: 100% !important;
#     max-width: 100% !important;
#     padding-bottom: 10px;
# }
#
# /* Force light background for code input/output (fix dark issue) */
# div.input_area pre,
# .jp-InputArea-editor pre,
# .code_cell pre,
# .output_area pre {
#     background-color: #f7f7f7 !important;
#     color: #000000 !important;
#     border-radius: 6px !important;
#     border: 1px solid #ddd !important;
# }
#
# /* Keep overall code cell container consistent */
# .jp-CodeCell {
#     width: 100% !important;
#     max-width: 100% !important;
#     min-width: 0 !important;
#     overflow: hidden !important;
#     background-color: #ffffff !important;
# }
#
# /* Soften input area corners */
# .jp-InputArea-editor,
# div.input_area {
#     border-radius: 8px !important;
#     background-color: #ffffff !important;
#     border: 1px solid #ddd !important;
#     overflow: hidden !important;
# }
#
# /* Fix black background for message/output boxes */
# .jp-OutputArea-output,
# .output_subarea,
# .output_wrapper,
# .output_area pre,
# .jp-RenderedText,
# .jp-RenderedHTMLCommon pre {
#     background-color: #ffffff !important;
#     color: #000000 !important;
#     border-radius: 6px !important;
#     border: 1px solid #e0e0e0 !important;
# }
#
# /* Error/warning box visual */
# .jp-OutputArea-output-error,
# .output_error pre,
# .output_stderr pre {
#     background-color: #fff6f6 !important;
#     color: #b00000 !important;
#     border-radius: 6px !important;
#     border: 1px solid #f0c0c0 !important;
# }
#
# /* --- 3. MOBILE OVERRIDE: FORCE WRAP/SCROLL (CSS Media Query) --- */
# @media screen and (max-width: 480px) {
#     div.input_area pre,
#     .jp-InputArea-editor pre,
#     .code_cell pre,
#     div.text_cell pre {
#         white-space: pre-wrap !important;
#         word-wrap: break-word !important;
#         overflow-x: hidden !important;
#     }
#
#     .output_subarea,
#     .output_wrapper,
#     .output_html,
#     .output_area table,
#     .output_area table * {
#         overflow-x: auto !important;
#         width: auto !important;
#         min-width: 100% !important;
#     }
#
#     .output_area table {
#         display: block !important;
#         min-width: 100%;
#     }
#
#     .output_area table td, .output_area table th {
#         white-space: nowrap !important;
#     }
# }
#
# /* --- 4. STYLE MARKDOWN CODE BLOCKS (Visuals) --- */
# div.text_cell pre code,
# div.text_cell pre {
#     background-color: var(--jp-layout-color1, #f7f7f7) !important;
#     padding: 10px;
#     border-radius: 4px;
#     border: 1px solid var(--jp-border-color2, #ccc) !important;
#     max-width: 100%;
#     color: #000000 !important;
# }
#
# /* --- 5. FINAL FIX: Handle dark stderr/warning boxes (like FutureWarning) --- */
# .output_stderr,
# .jp-RenderedText[data-mime-type="application/vnd.jupyter.stderr"],
# .jp-OutputArea-output[data-mime-type="application/vnd.jupyter.stderr"] {
#     background-color: #fff6f6 !important; /* light red for visibility */
#     color: #b00000 !important;
#     border: 1px solid #f0c0c0 !important;
#     border-radius: 6px !important;
# }
# </style>

# %% [markdown]
# [Imtiaj.](https://imtiajiqbalmahfuj.github.io/index.html#top)

# %% [markdown]
# # 🌊 Padma River Desiccation Mapping (2001–2025)
# ### Tracking 25 Years of Surface Water Change in Rajshahi Using Python & Google Earth Engine
#
# ![Project Preview](https://raw.githubusercontent.com/imtiajiqbalmahfuj/imtiajiqbal-portfolio/refs/heads/main/Projects/25025%20River%20Desiccation%20Mapping%2C%20Rajshahi/River_Desiccation.png)
#
# ![Date](https://img.shields.io/badge/01/11/2025-01/11/2025-blue)
# ![Location](https://img.shields.io/badge/Location-Rajshahi-blue)
# ---
# > **Author:** Imtiaj Iqbal Mahfuj
# ---
#
# ## 📝 Overview
# This project investigates the **desiccation of the Padma River** over a 25-year period (2001–2025), focusing on the **Rajshahi region** of Bangladesh. The Padma River, one of the most critical river systems in South Asia, has shown significant **hydrological and morphological changes** in recent decades due to both natural and anthropogenic pressures.
#
# By leveraging **MODIS Surface Reflectance data (MOD09A1)**, this study computes the **Normalized Difference Water Index (NDWI)** annually to assess temporal changes in surface water extent.
#
# The main objectives include:
# - Quantifying long-term changes in the Padma River’s surface water.
# - Visualizing annual variations in NDWI to identify desiccation trends.
# - Demonstrating how open-source geospatial Python tools can be used for time-series river analysis.
#
# This analysis is relevant for **hydrologists, climate researchers, planners, and policy-makers** seeking to understand **river health**, **climate impacts**, and **sustainable water management** strategies.
#
# ---
#
# ## 🛠️ Tools & Technologies
# ![GeoPy](https://img.shields.io/badge/Geospatial-Python-magenta)
# ![GEE](https://img.shields.io/badge/Google%20Earth%20Engine-API-purple)
# ![Xarray](https://img.shields.io/badge/Xarray-MultiDimData-lightgrey)
# ![Matplotlib](https://img.shields.io/badge/Visualization-Matplotlib-green)
# ![MODIS](https://img.shields.io/badge/Satellite-MODIS-red)
#
# ---
#
# ## ⚙️ Methodology
# | Step | Description |
# |------|-------------|
# | **1. Data Collection** | MODIS Surface Reflectance (MOD09A1) from Google Earth Engine (2001–2025). |
# | **2. Preprocessing** | Selected NIR (`sur_refl_b02`) and Green (`sur_refl_b04`) bands, clipped to Rajshahi AOI. |
# | **3. Analysis** | Computed NDWI = (Green - NIR) / (Green + NIR) for each timestep; aggregated annually. |
# | **4. Visualization** | Used `xarray` and `matplotlib` to plot 25 annual NDWI frames showing water area changes. |
#
# ---
#
# ## Codes

# %%
import ee
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt
import xee

# %%
ee.Authenticate()
ee.Initialize()

# %%
modis = (
    ee.ImageCollection("MODIS/061/MOD09A1")\
    .select('sur_refl_b02','sur_refl_b04')\
    .filterDate('2001','2025')
)

# %%
aoi = ee.Geometry.Rectangle([88.45694402418187, 24.057944340289367, 
                             89.05157903394749, 24.392323604959078])

# %%
ds = xr.open_dataset(modis, engine = 'ee', crs = 'EPSG:4326', scale= 0.01, geometry= aoi)

# %%
ds
# Out:
# <xarray.Dataset> Size: 17MB
# Dimensions:       (time: 1103, lon: 59, lat: 33)
# Coordinates:
#   * time          (time) datetime64[ns] 9kB 2001-01-01 2001-01-09 ... 2024-12-26
#   * lon           (lon) float64 472B 88.46 88.47 88.48 ... 89.02 89.03 89.04
#   * lat           (lat) float64 264B 24.06 24.07 24.08 ... 24.36 24.37 24.38
# Data variables:
#     sur_refl_b02  (time, lon, lat) float32 9MB ...
#     sur_refl_b04  (time, lon, lat) float32 9MB ...
# Attributes:
#     crs:      EPSG:4326

# %%
green = ds.sur_refl_b04 * 0.0001
nir = ds.sur_refl_b02 * 0.0001

# %%
nir
# Out:
# <xarray.DataArray 'sur_refl_b02' (time: 1103, lon: 59, lat: 33)> Size: 9MB
# array([[[0.20879999, 0.2227    , 0.2455    , ..., 0.21779999,
#          0.1138    , 0.218     ],
#         [0.22029999, 0.2077    , 0.2417    , ..., 0.1709    ,
#          0.19749999, 0.2298    ],
#         [0.2302    , 0.22389999, 0.23179999, ..., 0.1925    ,
#          0.2505    , 0.2421    ],
#         ...,
#         [0.166     , 0.1698    , 0.17019999, ..., 0.2025    ,
#          0.19739999, 0.2041    ],
#         [0.13599999, 0.1391    , 0.15709999, ..., 0.2042    ,
#          0.20009999, 0.21689999],
#         [0.1978    , 0.19      , 0.1775    , ..., 0.20969999,
#          0.2048    , 0.1953    ]],
#
#        [[0.1788    , 0.1946    , 0.22129999, ..., 0.1986    ,
#          0.1612    , 0.1881    ],
#         [0.185     , 0.16239999, 0.2145    , ..., 0.1734    ,
#          0.18339999, 0.20459999],
#         [0.1994    , 0.2017    , 0.1999    , ..., 0.17      ,
#          0.20709999, 0.20809999],
# ...

# %%
ndwi = (green - nir) / (green + nir)

# %%
ndwi
# Out:
# <xarray.DataArray (time: 1103, lon: 59, lat: 33)> Size: 9MB
# array([[[-0.42525598, -0.4307742 , -0.44880494, ..., -0.1980198 ,
#           0.05127139, -0.2403983 ],
#         [-0.41763192, -0.390693  , -0.46796235, ..., -0.07450487,
#          -0.2555626 , -0.35495284],
#         [-0.46670914, -0.434337  , -0.45740333, ..., -0.06236202,
#          -0.3577236 , -0.36625287],
#         ...,
#         [-0.1563915 , -0.16660942, -0.18523675, ..., -0.38461542,
#          -0.3794549 , -0.39412567],
#         [-0.02294095, -0.05618833, -0.12334643, ..., -0.3895883 ,
#          -0.3997901 , -0.41210938],
#         [-0.2424623 , -0.2406138 , -0.2806638 , ..., -0.39799997,
#          -0.3965223 , -0.36573425]],
#
#        [[-0.41623765, -0.44684017, -0.48723122, ..., -0.14137931,
#          -0.07538363, -0.22460938],
#         [-0.4252697 , -0.3550271 , -0.4803313 , ..., -0.09955615,
#          -0.18936445, -0.30734825],
#         [-0.48861516, -0.4771146 , -0.4851412 , ..., -0.07697184,
# ...

# %%
ndwi_annual = ndwi.resample(time = 'Y').mean('time')
# Out:
# C:\Users\User\anaconda3\envs\geopy\Lib\site-packages\xarray\groupers.py:392: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   self.index_grouper = pd.Grouper(

# %%
ndwi_annual
# Out:
# <xarray.DataArray (time: 24, lon: 59, lat: 33)> Size: 187kB
# array([[[-0.44337085, -0.41348684, -0.4084922 , ..., -0.16735625,
#          -0.0609958 , -0.2031305 ],
#         [-0.44265854, -0.4023658 , -0.41442606, ..., -0.10046277,
#          -0.2470318 , -0.3491469 ],
#         [-0.44812205, -0.44260234, -0.43128434, ..., -0.13800989,
#          -0.35215846, -0.37262014],
#         ...,
#         [-0.172704  , -0.228267  , -0.23969507, ..., -0.42176303,
#          -0.42922974, -0.42251083],
#         [-0.05805749, -0.10195709, -0.06248063, ..., -0.42113063,
#          -0.44368374, -0.4450672 ],
#         [-0.23645288, -0.26823962, -0.3022437 , ..., -0.43587592,
#          -0.43460295, -0.42784312]],
#
#        [[-0.46955097, -0.46135798, -0.45701915, ..., -0.11146554,
#          -0.07502924, -0.21053457],
#         [-0.45407516, -0.449579  , -0.4656027 , ..., -0.07017343,
#          -0.25990158, -0.352957  ],
#         [-0.47971   , -0.4543452 , -0.4563002 , ..., -0.10397074,
# ...

# %%
ndwi_annual.plot(x='lon', y= 'lat', cmap= 'Blues', col = 'time', col_wrap = 5, robust = True)
plt.suptitle("River Desiccation Mapping of Rajshahi using Python", x=.45, y=1.03, size=24, weight='bold')
plt.figtext(0.8, 0.045, 'Imtiaj Iqbal', 
            horizontalalignment='right', 
            fontsize=14, 
            color='gray')
plt.savefig('River_Desiccation.png', dpi = 360, bbox_inches='tight')

# %% [markdown]
# *Caption: Annual NDWI composites (2001–2025) revealing long-term desiccation trends along the Padma River.*
#
# ## 📊 Results & Insights
# - 🔹 Clear **decline in water presence** along the Padma River in the Rajshahi region from 2001 to 2025.
# - 🔹 NDWI trends show **progressive desiccation** of floodplains and reduction in seasonal water coverage.
# - 🔹 Visual evidence of **riverbank erosion and shifting river channels** over two decades.
#
# ---
#
# ## ❓ Why this project?
# - The Padma River plays a key role in **Bangladesh’s hydrology and ecosystem stability**, yet **systematic long-term analyses** of its desiccation have been limited.
# - This project bridges that gap by offering **temporal mapping and visualization** using **open-source geospatial tools**.
# - Insights can inform **river basin management**, **climate adaptation**, and **policy planning** for sustainable river conservation.
#
# ---
#
# ## ✨ Features
# - 📅 Multi-temporal NDWI computation (2001–2025)
# - 🌊 River desiccation mapping and trend visualization
# - 🧠 Python–GEE integration using `xee`
# - 🖼️ Exportable maps in PNG format
# - 🧾 Ready-to-use workflow for hydrological change detection
#
# ---
#
# ## 📎 Links
# - 🔗 [See more in LinkedIn](https://linkedin.com/in/imtiajiqbalmahfuj)
# - 🎥 [Inspiration Video – Milos Makes Maps](https://youtu.be/B2jAPuMEctI?si=KenuzjtYJOieKzT4)
# - 📄 [Personal Portfolio](https://imtiajiqbalmahfuj.github.io/)
#
# ---
#
# ## 🔖 Tags
# `GIS` `Remote Sensing` `Python` `Google Earth Engine` `NDWI` `River Desiccation` `Hydrology` `Climate Change` `Rajshahi`
#
# ---
#
# ## 📌 Credits & Shoutouts
# - 👨‍💻 **Author:** [Imtiaj Iqbal Mahfuj](https://imtiajiqbalmahfuj.github.io/)
# - 🙌 **Inspiration:** *Amirhossein Ahrar* (for GEE–Python integration workflow)
# - 🗂️ **Data Source:** MODIS Surface Reflectance (MOD09A1) — NASA / USGS via Google Earth Engine
#
# ---
#
# ## 💬 Connect with Me
# 📧 Email: imtiajiqbal.ruet@gmail.com
# 🌐 Portfolio: [https://imtiajiqbalmahfuj.github.io/](https://imtiajiqbalmahfuj.github.io/)
